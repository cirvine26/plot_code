# %% [markdown]
# <a href="https://colab.research.google.com/github/cirvine26/plot_code/blob/master/Plot_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''This module will function as a template to plot graphs. Useful for labs.'''

import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib notebook
from openpyxl import load_workbook

wb=load_workbook('Insert_workbook_directory.xlsx')
sheet_1=wb['Sheet1']

#Set of readings
x_0=np.zeros(43)
y_0=np.zeros(43)
dy_0=np.zeros(43) #Error bars for y

for i in range(0,43):
    x_0[i]=sheet_1.cell(row=i+3, column=37).value
    y_0[i]=sheet_1.cell(row=i+3, column=38).value
    dy_0[i]=sheet_1.cell(row=i+3, column=39).value
    
for i in range(0,58):
    x_b1[i]=sheet_1.cell(row=i+3, column=46).value
    y_b1[i]=sheet_1.cell(row=i+3, column=47).value
    dy_b1[i]=sheet_1.cell(row=i+3, column=48).value
    
#Trendline Calculation if needed
#z_b0 = np.polyfit(x_b0, y_b0, 1)
#p_b0 = np.poly1d(z_b0)

#z_b1 = np.polyfit(x_b1, y_b1, 1)
#p_b1 = np.poly1d(z_b1)

#Plot commands
plt.scatter(x_b0,y_b0,s=7.5)
plt.errorbar(x_b0,y_b0,yerr=dy_b0, linestyle='None', color='k')
plt.plot(x_b0,p_b0(x_b0),"b--")

#plt.scatter(x_b1,y_b1,s=7.5)
#plt.errorbar(x_b1,y_b1,yerr=dy_b1, linestyle='None', color='k')
#plt.plot(x_b1,p_b1(x_b1),"b--")


plt.xlabel('Tip Distance from Sample(nm)')
plt.ylabel('ln(Detected Current/nA)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0,0.5,'ln(Detected Current/nA)')
